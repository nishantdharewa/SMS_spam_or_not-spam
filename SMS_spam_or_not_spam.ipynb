# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report
df = pd.read_csv("/content/spam_texts.csv")

# %%
df=pd.DataFrame(data)
df
# Out:
#             image                                               text
# 0    images/0.jpg  CREDITED: Rs.75 wallet money. Use it to order ...
# 1    images/1.jpg  Shoe styles paired with minimal looks, perfect...
# 2    images/2.jpg  Kejani Cleaning Services offers comprehensive,...
# 3    images/3.png  Carrefour Fridays month is on!! Crazy deals ev...
# 4    images/4.jpg  Keep up with MTN Broadband! Visit https://apps...
# 5    images/5.jpg  Get clientele HELP Cover today. Debi check and...
# 6    images/6.png  Do you like your friend's signature? Reply wit...
# 7    images/7.jpg  Get 2.5GB + 100 Telkom Mins +2 Bob/ Min to oth...
# 8    images/8.png  Enjoy more talktime when you recharge your Air...
# 9    images/9.png  25% Discount - Get Ultra 50GB from MyTelenor A...
# 10  images/10.jpg  Discount of Rs 100 is now YOURS! Get 126 Chann...
# 11  images/11.jpg  Ride & save with 25% off 5 GO or GO Awfar ride...
# 12  images/12.jpg  Study in UK, USA, Canada, Australia, Malaysia,...
# ...

# %%
df.isna().sum()
# Out:
# image    0
# text     0
# dtype: int64

# %%
print(df.head())
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df = df[['v1', 'v2']]
df.columns = ['label', 'text']
df['label'] = df['label'].map({'ham': 0, 'spam': 1})
# Out:
# <ipython-input-5-248e4a9037aa>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['label'] = df['label'].map({'ham': 0, 'spam': 1})

# %%
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['label'], test_size=0.2, random_state=42)

# %%
vectorizer = CountVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
model = MultinomialNB()
model.fit(X_train_vec, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_test_vec)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.9838565022421525
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       965
#            1       0.99      0.89      0.94       150
#
#     accuracy                           0.98      1115
#    macro avg       0.98      0.95      0.96      1115
# weighted avg       0.98      0.98      0.98      1115
#
#
# Confusion Matrix:
#  [[963   2]
#  [ 16 134]]

# %%
new_sms = ["Free gifts for you! Click here now!", "Hello dear, how are you?"]
new_sms_vec = vectorizer.transform(new_sms)
predictions = model.predict(new_sms_vec)

for sms, prediction in zip(new_sms, predictions):
    print(f"{sms} - {'Spam' if prediction == 1 else 'Non-Spam'}")

print("Free gifts for you! Click here now! - Spam")
print("Hello dear, how are you? - Non-Spam")
# Out:
# Free gifts for you! Click here now! - Spam
# Hello dear, how are you? - Non-Spam
# Free gifts for you! Click here now! - Spam
# Hello dear, how are you? - Non-Spam
